# %% [markdown]
# # Getting Data from the user:

# %%
#@title Upload Historical Data:

#@markdown ---

from google.colab import files

uploaded = files.upload()

file_name = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-97c609cf-d818-42f3-99f4-075d412da868" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97c609cf-d818-42f3-99f4-075d412da868">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Student_Performance_Data.xlsx to Student_Performance_Data.xlsx

# %%
#@title Select the Semester and Paper(s): { run: "auto" }

#@markdown ### Select Semester:

Semester = 'Sem_6' #@param ["Sem_1", "Sem_2", "Sem_3", "Sem_4", "Sem_5", "Sem_6", "Sem_7", "Sem_8"]
key = Semester

#@markdown ### Enter Marks Threshold:

marks_thresh = 75 #@param {type:"slider", min:0, max:100, step:1}

#@markdown ### Enter Minimum Support:
minsup = 0.2 #@param {type:"number"}

#@markdown ### Enter Minimum Confidence:
minconf = 0.48 #@param {type:"number"}

# %% [markdown]
# # Code:

# %% [markdown]
# ## Importing Libraries:

# %%
import pandas as pd
import numpy as np
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Preparing the Data

# %%
df = pd.read_excel(file_name, sheet_name='Sheet1')
df.head()
# Out:
#     Student_ID Semster_Name     Paper_ID Paper_Name  Marks
# 0  SID20131143        Sem_1  SEMI0012995    Paper 1     44
# 1  SID20131143        Sem_1  SEMI0015183    Paper 2     74
# 2  SID20131143        Sem_1  SEMI0018371    Paper 3     80
# 3  SID20131143        Sem_1  SEMI0015910    Paper 4     44
# 4  SID20131143        Sem_1  SEMI0016208    Paper 5     95

# %%
df_dict_sem = {}
for name in df['Semster_Name'].unique():
    df_dict_sem[name] = df[df['Semster_Name'] == name].reset_index(drop=True)
df_dict_sem
# Out:
# {'Sem_1':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_1  SEMI0012995    Paper 1     44
#  1      SID20131143        Sem_1  SEMI0015183    Paper 2     74
#  2      SID20131143        Sem_1  SEMI0018371    Paper 3     80
#  3      SID20131143        Sem_1  SEMI0015910    Paper 4     44
#  4      SID20131143        Sem_1  SEMI0016208    Paper 5     95
#  ...            ...          ...          ...        ...    ...
#  26197  SID20189989        Sem_1  SEMI0018371    Paper 3     70
#  26198  SID20189989        Sem_1  SEMI0015910    Paper 4     41
#  26199  SID20189989        Sem_1  SEMI0016208    Paper 5     80
#  26200  SID20189989        Sem_1  SEMI0017431    Paper 6     49
#  26201  SID20189989        Sem_1  SEMI0014130    Paper 7     75
#
#  [26202 rows x 5 columns],
#  'Sem_2':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_2  SEMI0024747    Paper 1     92
#  1      SID20131143        Sem_2  SEMI0025909    Paper 2     57
#  2      SID20131143        Sem_2  SEMI0022443    Paper 3     91
#  3      SID20131143        Sem_2  SEMI0025077    Paper 4     84
#  4      SID20131143        Sem_2  SEMI0029604    Paper 5     80
#  ...            ...          ...          ...        ...    ...
#  26191  SID20189989        Sem_2  SEMI0022443    Paper 3     77
#  26192  SID20189989        Sem_2  SEMI0025077    Paper 4     70
#  26193  SID20189989        Sem_2  SEMI0029604    Paper 5     78
#  26194  SID20189989        Sem_2  SEMI0029061    Paper 6     87
#  26195  SID20189989        Sem_2  SEMI0022256    Paper 7     46
#
#  [26196 rows x 5 columns],
#  'Sem_3':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_3  SEMI0037924    Paper 1     76
#  1      SID20131143        Sem_3  SEMI0034580    Paper 2     83
#  2      SID20131143        Sem_3  SEMI0033576    Paper 3     41
#  3      SID20131143        Sem_3  SEMI0031818    Paper 4     80
#  4      SID20131143        Sem_3  SEMI0039951    Paper 5     69
#  ...            ...          ...          ...        ...    ...
#  26197  SID20189989        Sem_3  SEMI0033576    Paper 3     67
#  26198  SID20189989        Sem_3  SEMI0031818    Paper 4     54
#  26199  SID20189989        Sem_3  SEMI0039951    Paper 5     61
#  26200  SID20189989        Sem_3  SEMI0039037    Paper 6     86
#  26201  SID20189989        Sem_3  SEMI0035955    Paper 7     91
#
#  [26202 rows x 5 columns],
#  'Sem_4':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_4  SEMI0044637    Paper 1     78
#  1      SID20131143        Sem_4  SEMI0048491    Paper 2     83
#  2      SID20131143        Sem_4  SEMI0049197    Paper 3     94
#  3      SID20131143        Sem_4  SEMI0044506    Paper 5     99
#  4      SID20131143        Sem_4  SEMI0044518    Paper 6    100
#  ...            ...          ...          ...        ...    ...
#  26171  SID20189989        Sem_4  SEMI0049197    Paper 3     71
#  26172  SID20189989        Sem_4  SEMI0047507    Paper 4     49
#  26173  SID20189989        Sem_4  SEMI0044506    Paper 5     62
#  26174  SID20189989        Sem_4  SEMI0044518    Paper 6     72
#  26175  SID20189989        Sem_4  SEMI0044275    Paper 7     86
#
#  [26176 rows x 5 columns],
#  'Sem_5':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_5  SEMI0058624    Paper 1     92
#  1      SID20131143        Sem_5  SEMI0058693    Paper 2     44
#  2      SID20131143        Sem_5  SEMI0056942    Paper 3     69
#  3      SID20131143        Sem_5  SEMI0055343    Paper 4     60
#  4      SID20131143        Sem_5  SEMI0052593    Paper 5     97
#  ...            ...          ...          ...        ...    ...
#  26212  SID20189989        Sem_5  SEMI0056942    Paper 3     90
#  26213  SID20189989        Sem_5  SEMI0055343    Paper 4     92
#  26214  SID20189989        Sem_5  SEMI0052593    Paper 5     92
#  26215  SID20189989        Sem_5  SEMI0055015    Paper 6     92
#  26216  SID20189989        Sem_5  SEMI0052434    Paper 7     61
#
#  [26217 rows x 5 columns],
#  'Sem_6':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_6  SEMI0068923    Paper 1     98
#  1      SID20131143        Sem_6  SEMI0067259    Paper 2     84
#  2      SID20131143        Sem_6  SEMI0065623    Paper 3     46
#  3      SID20131143        Sem_6  SEMI0064181    Paper 4     76
#  4      SID20131143        Sem_6  SEMI0064427    Paper 5     54
#  ...            ...          ...          ...        ...    ...
#  26184  SID20189989        Sem_6  SEMI0065623    Paper 3     45
#  26185  SID20189989        Sem_6  SEMI0064181    Paper 4     60
#  26186  SID20189989        Sem_6  SEMI0064427    Paper 5     98
#  26187  SID20189989        Sem_6  SEMI0069632    Paper 6     85
#  26188  SID20189989        Sem_6  SEMI0069737    Paper 7     95
#
#  [26189 rows x 5 columns],
#  'Sem_7':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_7  SEMI0076821    Paper 1     94
#  1      SID20131143        Sem_7  SEMI0071868    Paper 2     53
#  2      SID20131143        Sem_7  SEMI0077220    Paper 3     54
#  3      SID20131143        Sem_7  SEMI0078668    Paper 4     88
#  4      SID20131143        Sem_7  SEMI0073367    Paper 5     86
#  ...            ...          ...          ...        ...    ...
#  26231  SID20189989        Sem_7  SEMI0077220    Paper 3     63
#  26232  SID20189989        Sem_7  SEMI0078668    Paper 4     44
#  26233  SID20189989        Sem_7  SEMI0073367    Paper 5     58
#  26234  SID20189989        Sem_7  SEMI0079276    Paper 6     92
#  26235  SID20189989        Sem_7  SEMI0078510    Paper 7     52
#
#  [26236 rows x 5 columns],
#  'Sem_8':         Student_ID Semster_Name     Paper_ID Paper_Name  Marks
#  0      SID20131143        Sem_8  SEMI0089747    Paper 1     58
#  1      SID20131143        Sem_8  SEMI0081989    Paper 2     64
#  2      SID20131143        Sem_8  SEMI0082598    Paper 3     42
#  3      SID20131143        Sem_8  SEMI0088030    Paper 4     98
#  4      SID20131143        Sem_8  SEMI0081794    Paper 5     62
#  ...            ...          ...          ...        ...    ...
#  26188  SID20189989        Sem_8  SEMI0082598    Paper 3     94
#  26189  SID20189989        Sem_8  SEMI0088030    Paper 4     49
#  26190  SID20189989        Sem_8  SEMI0081794    Paper 5     47
#  26191  SID20189989        Sem_8  SEMI0086600    Paper 6     87
#  26192  SID20189989        Sem_8  SEMI0083259    Paper 7     73
#
#  [26193 rows x 5 columns]}

# %%
df_sem = df_dict_sem[key]
df_sem.head()
# Out:
#     Student_ID Semster_Name     Paper_ID Paper_Name  Marks
# 0  SID20131143        Sem_6  SEMI0068923    Paper 1     98
# 1  SID20131143        Sem_6  SEMI0067259    Paper 2     84
# 2  SID20131143        Sem_6  SEMI0065623    Paper 3     46
# 3  SID20131143        Sem_6  SEMI0064181    Paper 4     76
# 4  SID20131143        Sem_6  SEMI0064427    Paper 5     54

# %%
#Applying Marks Threshold
df_sem_marks_thresh = df_sem[df_sem['Marks'] > marks_thresh].reset_index(drop=True)
df_sem_marks_thresh.head()
# Out:
#     Student_ID Semster_Name     Paper_ID Paper_Name  Marks
# 0  SID20131143        Sem_6  SEMI0068923    Paper 1     98
# 1  SID20131143        Sem_6  SEMI0067259    Paper 2     84
# 2  SID20131143        Sem_6  SEMI0064181    Paper 4     76
# 3  SID20131151        Sem_6  SEMI0065623    Paper 3     87
# 4  SID20131151        Sem_6  SEMI0064181    Paper 4     92

# %%
#getting only the sudent ID and the paper name
df_sem_marks_thresh_ID_Paper = df_sem_marks_thresh[['Student_ID', 'Paper_Name']]
df_sem_marks_thresh_ID_Paper
# Out:
#         Student_ID Paper_Name
# 0      SID20131143    Paper 1
# 1      SID20131143    Paper 2
# 2      SID20131143    Paper 4
# 3      SID20131151    Paper 3
# 4      SID20131151    Paper 4
# ...            ...        ...
# 10580  SID20189982    Paper 2
# 10581  SID20189982    Paper 3
# 10582  SID20189989    Paper 5
# 10583  SID20189989    Paper 6
# 10584  SID20189989    Paper 7
#
# [10585 rows x 2 columns]

# %% [markdown]
# ## Installing fpgrowth_py:

# %%
pip install fpgrowth_py
# Out:
# Collecting fpgrowth_py
#   Downloading fpgrowth_py-1.0.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: fpgrowth-py
# Successfully installed fpgrowth-py-1.0.0

# %% [markdown]
# ## Converting data and executing:

# %%
from fpgrowth_py import fpgrowth

# %%
df_sem_encoded = df_sem_marks_thresh_ID_Paper.groupby(['Student_ID'], axis=0)['Paper_Name'].transform(lambda x : ','.join(x))
df_sem_encoded.head()
# Out:
# 0    Paper 1,Paper 2,Paper 4
# 1    Paper 1,Paper 2,Paper 4
# 2    Paper 1,Paper 2,Paper 4
# 3            Paper 3,Paper 4
# 4            Paper 3,Paper 4
# Name: Paper_Name, dtype: object

# %%
sem_itemlist = [value.split(',') for value in df_sem_encoded.values.tolist()]
sem_itemlist
# Out:
# [['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 7'],
#  ['Paper 5'],
#  ['Paper 1'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 2'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 4'],
#  ['Paper 2', 'Paper 4'],
#  ['Paper 4'],
#  ['Paper 2', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1'],
#  ['Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 4'],
#  ['Paper 4'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 4'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5'],
#  ['Paper 2', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 6'],
#  ['Paper 1', 'Paper 6'],
#  ['Paper 1'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 5'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4'],
#  ['Paper 1', 'Paper 4'],
#  ['Paper 1', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 4', 'Paper 6'],
#  ['Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 2', 'Paper 6'],
#  ['Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 4'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 5'],
#  ['Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3'],
#  ['Paper 2', 'Paper 3'],
#  ['Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 4'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 6'],
#  ['Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 4', 'Paper 5'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4'],
#  ['Paper 1', 'Paper 4'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 4'],
#  ['Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 1'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3'],
#  ['Paper 2', 'Paper 3'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 7'],
#  ['Paper 2', 'Paper 6'],
#  ['Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 5'],
#  ['Paper 4'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 5'],
#  ['Paper 2', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 2', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 7'],
#  ['Paper 1', 'Paper 7'],
#  ['Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 1'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 4'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4'],
#  ['Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 1', 'Paper 2'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 4', 'Paper 6'],
#  ['Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 2', 'Paper 4'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 7'],
#  ['Paper 1', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 4', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 2'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 3'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 6'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3'],
#  ['Paper 2', 'Paper 5'],
#  ['Paper 2', 'Paper 5'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 3', 'Paper 4'],
#  ['Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 2', 'Paper 3'],
#  ['Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 2', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 6'],
#  ['Paper 4', 'Paper 6'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 5', 'Paper 6'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 5', 'Paper 7'],
#  ['Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 3', 'Paper 6'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 5'],
#  ['Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 7'],
#  ['Paper 2'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 3', 'Paper 4'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 1', 'Paper 5'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 4', 'Paper 5', 'Paper 7'],
#  ['Paper 7'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3', 'Paper 5'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 1', 'Paper 3'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 2', 'Paper 3', 'Paper 4', 'Paper 5'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 1', 'Paper 4', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 4', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 6', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 2', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 1', 'Paper 5', 'Paper 6', 'Paper 7'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 4', 'Paper 7'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 3', 'Paper 7'],
#  ['Paper 3'],
#  ['Paper 2', 'Paper 3'],
#  ['Paper 2', 'Paper 3'],
#  ['Paper 1', 'Paper 6'],
#  ['Paper 1', 'Paper 6'],
#  ['Paper 2', 'Paper 6'],
#  ['Paper 2', 'Paper 6'],
#  ...]

# %%
freqItemSet, rules = fpgrowth(sem_itemlist, minsup, minconf)

# %%
rules
# Out:
# [[{'Paper 4'}, {'Paper 7'}, 0.48778044871794873],
#  [{'Paper 3'}, {'Paper 5'}, 0.48050662972491587],
#  [{'Paper 3'}, {'Paper 1'}, 0.48129823867009697],
#  [{'Paper 3'}, {'Paper 7'}, 0.48664159905006926],
#  [{'Paper 6'}, {'Paper 5'}, 0.4842166796570538],
#  [{'Paper 7'}, {'Paper 6'}, 0.4815378759040731],
#  [{'Paper 6'}, {'Paper 7'}, 0.4929851909586906],
#  [{'Paper 5'}, {'Paper 7'}, 0.4855212355212355]]

# %%
freqItemSet
# Out:
# [{'Paper 4'},
#  {'Paper 4', 'Paper 6'},
#  {'Paper 1', 'Paper 4'},
#  {'Paper 4', 'Paper 5'},
#  {'Paper 2', 'Paper 4'},
#  {'Paper 3', 'Paper 4'},
#  {'Paper 4', 'Paper 7'},
#  {'Paper 3'},
#  {'Paper 2', 'Paper 3'},
#  {'Paper 3', 'Paper 6'},
#  {'Paper 3', 'Paper 5'},
#  {'Paper 1', 'Paper 3'},
#  {'Paper 3', 'Paper 7'},
#  {'Paper 2'},
#  {'Paper 2', 'Paper 6'},
#  {'Paper 1', 'Paper 2'},
#  {'Paper 2', 'Paper 5'},
#  {'Paper 2', 'Paper 7'},
#  {'Paper 6'},
#  {'Paper 1', 'Paper 6'},
#  {'Paper 5', 'Paper 6'},
#  {'Paper 6', 'Paper 7'},
#  {'Paper 1'},
#  {'Paper 1', 'Paper 5'},
#  {'Paper 1', 'Paper 7'},
#  {'Paper 5'},
#  {'Paper 5', 'Paper 7'},
#  {'Paper 7'}]

# %% [markdown]
# # Final Result:

# %%
for item in freqItemSet:
    if len(item) > 1:
        print(item)
# Out:
# {'Paper 6', 'Paper 4'}
# {'Paper 1', 'Paper 4'}
# {'Paper 4', 'Paper 5'}
# {'Paper 4', 'Paper 2'}
# {'Paper 3', 'Paper 4'}
# {'Paper 4', 'Paper 7'}
# {'Paper 3', 'Paper 2'}
# {'Paper 3', 'Paper 6'}
# {'Paper 3', 'Paper 5'}
# {'Paper 1', 'Paper 3'}
# {'Paper 3', 'Paper 7'}
# {'Paper 6', 'Paper 2'}
# {'Paper 1', 'Paper 2'}
# {'Paper 5', 'Paper 2'}
# {'Paper 7', 'Paper 2'}
# {'Paper 1', 'Paper 6'}
# {'Paper 6', 'Paper 5'}
# {'Paper 6', 'Paper 7'}
# {'Paper 1', 'Paper 5'}
# {'Paper 1', 'Paper 7'}
# {'Paper 7', 'Paper 5'}
